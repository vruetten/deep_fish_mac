# %%
import numpy as np
import threading, serial, struct
from time import sleep
import pyqtgraph as pg
from PyQt5 import QtGui
from PyQt5.QtCore import Qt
import sys,os, re
from PyQt5 import QtCore
import matplotlib.pyplot as pl
# %gui qt
% matplotlib inline

# %%
A = MyArduino()

# %%
A.sendChar('a', True)
# Out:
#                 Data sent succesfully.
#                 Data sent: a
#                 Immediate response: 1

# %%
A.sendInteger(19,True)
# Out:
# Sent the integer 19 succesfully

# %%
A.readData(2, printData=True, array=True, integers=True)
# Out:
# received from PC: 19
# ard sent: 3
# ['None', 'None', 'None']

# %%
# ! python ~/Documents/deep_fish/run_pump/deep_fish.py

# %%
fig = pl.figure()
ax = fig.add_subplot(111)
ax.clear()
ax.imshow(im)
# ax.set_axis_off()
# ax.set_axis_off()
ax.set_frame_on(False)
ax.axes.get_xaxis().set_visible(False)
ax.axes.get_yaxis().set_visible(False)

# %%
s = 'hello 445'

# %%
if s.find('hell3o')==0:
    print('uo')

# %%
ser = serial.Serial('/dev/cu.usbmodem14311', 9600,timeout=.1)

# %%
def print_data():
    data = ser.readline().decode("utf-8") 
    print(data)

# %%
class RepeatedTimer(object):
    def __init__(self, interval, function, *args, **kwargs):
        self._timer     = None
        self.interval   = interval
        self.function   = function
        self.args       = args
        self.kwargs     = kwargs
        self.is_running = False
        self.start()

    def _run(self):
        self.is_running = False
        self.start()
        self.function(*self.args, **self.kwargs)

    def start(self):
        if not self.is_running:
#             threading.Timer(time, printit).start()
            self._timer = Timer(self.interval, self._run)
            self._timer.start()
            self.is_running = True

    def stop(self):
        self._timer.cancel()
        self.is_running = False

# %%
def write_2_ard():
    var = bytes(9)
    ser.write(var)
    tmp = ser.readline()
#     print(tmp)
#     print(tmp.decode("utf-8"))   
    return tmp.decode("utf-8")
for i in range(3):
    tmp = write_2_ard()
    if tmp.find('ard')>-1:
        print('yes')
        print(tmp)
    elif tmp.find('PC')>-1:
        print('no')
        print(tmp)
# Out:
# no
# PC received: 0
#
# yes
# ard sent: 1

# %%
import glob
from scipy.misc import imread
glob.glob('../assets/*')
# Out:
# ['../assets/pavlov_dog.jpg']

# %%
pl.imshow(tmp)

# %%
fig = pl.Figure()
ax = fig.add_subplot(111)

# %%
try:
    ax
except:
    print('jo')

# %%
if ax in globals():
    print('yes')

# %%
tmp = imread(file_path)
# Out:
# /Users/virginiarutten/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   if __name__ == '__main__':

# %%
file_path = '../assets/pavlov_dog.jpg'
file_path = '../assets/pp.png'
from PIL import Image
im = Image.open(file_path)

# %%
data = np.asarray(im)

# %%
data.shape
# Out:
# (120, 120, 4)

# %%
pl.imshow(im)

# %%
ser.write(30)
# Out:
# 30

# %%
import re

tmp = ser.readline()[:-2]
int(tmp)
# Out:
# 16

# %%
print ("starting...")
rt = RepeatedTimer(0.2, write_2_ard)
try:
    sleep(5) # your long-running job goes here...
finally:
    rt.stop()
# Out:
# starting...
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16

# %%
print ("starting...")


rt = RepeatedTimer(0.2, print_data)
try:
    sleep(1) # your long-running job goes here...
finally:
    rt.stop()
# Out:
# starting...
# 100
#
# hello
#
# 0
#
# 100

# %%
from time import sleep
import serial
ser = serial.Serial('/dev/tty.usbmodem1d11', 9600) # Establish the connection on a specific port
counter = 32 # Below 32 everything in ASCII is gibberish
while True:
     counter +=1
     ser.write('5') # Convert the decimal number to ASCII then send it to the Arduino
     print ser.readline() # Read the newest output from the Arduino
     sleep(.1) # Delay for one tenth of a second

# %%
file = '/Users/virginiarutten/Documents/deep_fish/run_pump/Users/virginiarutten/Documents/deep_fish/run_pump/deep_fish.py'

# %%
exec(open(file).read())

# %%
file
# Out:
# '/Users/virginiarutten/Documents/deep_fish/run_pump/Users/virginiarutten/Documents/deep_fish/run_pump/deep_fish.py'
